# %%
from functools import partial
import pickle as pkl
import sys
import os

sys.path.insert(0, "../../submodules/soepy")
sys.path.insert(0, "../../library")

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import soepy

from dev_library import get_criterion_function
from dev_library import plot_children_choices
from dev_library import plot_basics_choices
from dev_library import plot_basics_wages
from dev_library import df_alignment

# %% [markdown]
# ## Observed data

# %%
fname = "../../../data-exchange-sciebo/df-observed-data-weighted-subsample.pkl"
df_obs = pd.read_pickle(fname)

# %% [markdown]
# ## Parameterization

# %%
params_start = pd.read_pickle("start.soepy.pkl")
params_start
# Out:
#                                                  value    upper    lower  \
# category          name
# benefits_base                               200.000000  1000.00  100.000
# const_wage_eq     gamma_0s1                   2.045637     2.50    2.000
#                   gamma_0s2                   2.074695     2.50    2.000
#                   gamma_0s3                   2.139229     2.50    2.000
# delta                                         0.971317     0.99    0.900
# disutil_work      child_02_f                  2.293799     3.00   -0.000
#                   child_02_p                 -2.000000     0.00   -2.000
#                   child_35_f                  1.765292     2.00   -0.000
#                   child_35_p                 -1.042897     0.00   -2.000
#                   child_6orolder_f            1.662520     2.00   -0.000
#                   child_6orolder_p           -1.654465     0.00   -2.000
#                   no_kids_f_educ_high         0.523830     1.00   -0.000
#                   no_kids_f_educ_low          0.809566     1.25    0.750
#                   no_kids_f_educ_middle       0.185634     1.00   -0.000
#                   no_kids_p_educ_high        -0.378572     0.00   -1.000
#                   no_kids_p_educ_low         -0.568507    -0.00   -1.000
#                   no_kids_p_educ_middle      -0.303361     0.00   -1.000
#                   yes_kids_f_educ_high        0.723999     2.00   -0.000
#                   yes_kids_f_educ_low         0.931765     1.50    0.500
#                   yes_kids_f_educ_middle      1.082570     1.50    0.200
#                   yes_kids_p_educ_high       -0.573457     0.00   -1.000
#                   yes_kids_p_educ_low        -0.573503    -0.50   -1.000
#                   yes_kids_p_educ_middle     -0.857290     0.00   -1.000
# exp_accm          g_s1                        0.083693     0.50    0.001
#                   g_s2                        0.205770     0.50    0.001
#                   g_s3                        0.226319     0.50    0.001
# exp_accm_expected g_bar_s1                    0.570000     0.90    0.100
#                   g_bar_s2                    0.535000     0.90    0.100
#                   g_bar_s3                    0.625000     0.90    0.100
# exp_deprec        delta_s1                    0.020000     0.20    0.001
#                   delta_s2                    0.020000     0.20    0.001
#                   delta_s3                    0.020000     0.20    0.001
# exp_returns       gamma_1s1                   0.150909     0.20    0.050
#                   gamma_1s2                   0.262082     0.30    0.100
#                   gamma_1s3                   0.335623     0.50    0.001
# hetrg_unobs       theta_f1                   -0.861178    -0.10   -3.000
#                   theta_p1                   -0.409543    -0.10   -3.000
# mu                                           -0.392753    -0.99   -0.010
# sd_wage_shock     sigma_1                     0.336740     1.00    0.001
#                   sigma_2                     0.363327     1.00    0.001
# shares            share_1                     0.844696     0.90    0.100
# fval              fval                    16163.677199      NaN      NaN
#
#                                           fixed
# category          name
# benefits_base                              True
# const_wage_eq     gamma_0s1               False
#                   gamma_0s2               False
#                   gamma_0s3               False
# delta                                      True
# disutil_work      child_02_f              False
#                   child_02_p              False
#                   child_35_f              False
#                   child_35_p              False
#                   child_6orolder_f        False
#                   child_6orolder_p        False
#                   no_kids_f_educ_high     False
#                   no_kids_f_educ_low      False
#                   no_kids_f_educ_middle   False
#                   no_kids_p_educ_high     False
#                   no_kids_p_educ_low      False
#                   no_kids_p_educ_middle   False
#                   yes_kids_f_educ_high    False
#                   yes_kids_f_educ_low     False
#                   yes_kids_f_educ_middle  False
#                   yes_kids_p_educ_high    False
#                   yes_kids_p_educ_low     False
#                   yes_kids_p_educ_middle  False
# exp_accm          g_s1                     True
#                   g_s2                     True
#                   g_s3                     True
# exp_accm_expected g_bar_s1                 True
#                   g_bar_s2                 True
#                   g_bar_s3                 True
# exp_deprec        delta_s1                 True
#                   delta_s2                 True
#                   delta_s3                 True
# exp_returns       gamma_1s1               False
#                   gamma_1s2               False
#                   gamma_1s3               False
# hetrg_unobs       theta_f1                 True
#                   theta_p1                 True
# mu                                         True
# sd_wage_shock     sigma_1                  True
#                   sigma_2                  True
# shares            share_1                  True
# fval              fval                     True

# %% [markdown]
# ## Simulation

# %%
df_sim = soepy.simulate(params_start, "resources/model_spec_init.yml")
df_sim = df_alignment(df_sim)
df_sim.to_pickle("df_sim.soepy.pkl")

# %% [markdown]
# ## Plotting

# %%
plot_basics_choices(df_sim=df_sim, df_obs=df_obs)

# %%
plot_children_choices(df_sim=df_sim, df_obs=df_obs)

# %%
plot_basics_wages(df_sim=df_sim, df_obs=df_obs)
